# %% [markdown]
# ### 0. Importing modules and data

# %%
import pandas as pd
import os
import requests
from io import StringIO
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split

raw_df = pd.read_csv('../data/raw/bank-marketing-campaign-data.csv', delimiter=';')
raw_df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 1. Objective
# Whether the customer takes out a long-term deposit or not. Target: 'y'
#
# ### 2.Exploration and superficial cleaning
# #### 2.1 Problem dimensions

# %%
raw_df.shape
# Out:
# (41188, 21)

# %% [markdown]
# Our dataset have 41188 rows and 21 columns, so we have 21 features
#
# #### 2.2 Null values

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB

# %% [markdown]
# There are no null values in any column.

# %%
# copy raw_df and modify the copy, leaving the original dataframe unmodified
df = raw_df.copy()

# %% [markdown]
# #### 2.3 Duplicates
#
# As we don't have any row identifiers, we cannot detect duplicates.
#
# #### 2.5 Drop unuseful information

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
Nrows_nonexistent = (df['poutcome'] == 'nonexistent').sum()
Nrows_nonexistent
# Out:
# 35563

# %% [markdown]
# Since most of the entries did not exist in the previous campaign, this column does not provide information, so it can be removed

# %%
df.drop(["poutcome", "pdays", "education"], axis = 1, inplace = True)
df.head()
# Out:
#    age        job  marital  default housing loan    contact month day_of_week  \
# 0   56  housemaid  married       no      no   no  telephone   may         mon
# 1   57   services  married  unknown      no   no  telephone   may         mon
# 2   37   services  married       no     yes   no  telephone   may         mon
# 3   40     admin.  married       no      no   no  telephone   may         mon
# 4   56   services  married       no      no  yes  telephone   may         mon
#
#    duration  campaign  previous  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0       261         1         0           1.1          93.994          -36.4
# 1       149         1         0           1.1          93.994          -36.4
# 2       226         1         0           1.1          93.994          -36.4
# 3       151         1         0           1.1          93.994          -36.4
# 4       307         1         0           1.1          93.994          -36.4
#
#    euribor3m  nr.employed   y
# 0      4.857       5191.0  no
# 1      4.857       5191.0  no
# 2      4.857       5191.0  no
# 3      4.857       5191.0  no
# 4      4.857       5191.0  no

# %% [markdown]
# ### 3. Univariate analysis

# %%
fig, axis = plt.subplots(1, 2, figsize=(13, 5))

sns.histplot(df, x="month", ax=axis[0])
sns.histplot(df, x="day_of_week", ax=axis[1])
# Out:
# <Axes: xlabel='day_of_week', ylabel='Count'>

# %% [markdown]
# The majority of contacts are made in the month of May, and contacts are equally distributed across any weekday.
#
# ### 4. Multivariate analysis

# %%
agg_df = df.groupby(['y', 'housing', 'loan']).size().reset_index(name='count')

fig, axes = plt.subplots(1, 2, figsize=(14, 6))
sns.barplot(x='y', y='count', hue='housing', data=agg_df, palette='Set2',ax=axes[0],)
sns.barplot(x='y', y='count', hue='loan', data=agg_df, palette='Set2',ax=axes[1])
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %% [markdown]
# The majority of people who already have a mortgage or personal loan do not purchase the product

# %%
# Copy df to factorize categorics variables in a new dataframe
corr_df = df.copy()
corr_df.head()
# Out:
#    age        job  marital  default housing loan    contact month day_of_week  \
# 0   56  housemaid  married       no      no   no  telephone   may         mon
# 1   57   services  married  unknown      no   no  telephone   may         mon
# 2   37   services  married       no     yes   no  telephone   may         mon
# 3   40     admin.  married       no      no   no  telephone   may         mon
# 4   56   services  married       no      no  yes  telephone   may         mon
#
#    duration  campaign  previous  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 0       261         1         0           1.1          93.994          -36.4
# 1       149         1         0           1.1          93.994          -36.4
# 2       226         1         0           1.1          93.994          -36.4
# 3       151         1         0           1.1          93.994          -36.4
# 4       307         1         0           1.1          93.994          -36.4
#
#    euribor3m  nr.employed   y
# 0      4.857       5191.0  no
# 1      4.857       5191.0  no
# 2      4.857       5191.0  no
# 3      4.857       5191.0  no
# 4      4.857       5191.0  no

# %%
corr_df["job"] = pd.factorize(corr_df["job"])[0]
corr_df["marital"] = pd.factorize(corr_df["marital"])[0]
corr_df["default"] = pd.factorize(corr_df["default"])[0]
corr_df["housing"] = pd.factorize(corr_df["housing"])[0]
corr_df["loan"] = pd.factorize(corr_df["loan"])[0]
corr_df["contact"] = pd.factorize(corr_df["contact"])[0]
corr_df["month"] = pd.factorize(corr_df["month"])[0]
corr_df["day_of_week"] = pd.factorize(corr_df["day_of_week"])[0]
corr_df["y"] = pd.factorize(corr_df["y"])[0]

fig, axis = plt.subplots(figsize = (15, 15))

sns.heatmap(corr_df.corr(), annot = True, fmt = ".2f")
# Out:
# <Axes: >

# %% [markdown]
# About 10 variables seems to be relevant.

# %% [markdown]
# ### 5. Feature engineering
# #### 5.1 Outliers

# %%
corr_df.describe()
# Out:
#                age           job       marital       default       housing  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406      3.673691      0.510634      0.208872      0.571914
# std       10.42125      2.454116      0.696779      0.406686      0.541209
# min       17.00000      0.000000      0.000000      0.000000      0.000000
# 25%       32.00000      2.000000      0.000000      0.000000      0.000000
# 50%       38.00000      3.000000      0.000000      0.000000      1.000000
# 75%       47.00000      4.000000      1.000000      0.000000      1.000000
# max       98.00000     11.000000      3.000000      2.000000      2.000000
#
#                loan       contact         month   day_of_week      duration  \
# count  41188.000000  41188.000000  41188.000000  41188.000000  41188.000000
# mean       0.199767      0.634748      2.250097      1.979581    258.285010
# std        0.456002      0.481507      2.429079      1.411514    259.279249
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      1.000000    102.000000
# 50%        0.000000      1.000000      2.000000      2.000000    180.000000
# 75%        0.000000      1.000000      3.000000      3.000000    319.000000
# max        2.000000      1.000000      9.000000      4.000000   4918.000000
#
#            campaign      previous  emp.var.rate  cons.price.idx  \
# count  41188.000000  41188.000000  41188.000000    41188.000000
# mean       2.567593      0.172963      0.081886       93.575664
# std        2.770014      0.494901      1.570960        0.578840
# min        1.000000      0.000000     -3.400000       92.201000
# 25%        1.000000      0.000000     -1.800000       93.075000
# 50%        2.000000      0.000000      1.100000       93.749000
# 75%        3.000000      0.000000      1.400000       93.994000
# max       56.000000      7.000000      1.400000       94.767000
#
#        cons.conf.idx     euribor3m   nr.employed             y
# count   41188.000000  41188.000000  41188.000000  41188.000000
# mean      -40.502600      3.621291   5167.035911      0.112654
# std         4.628198      1.734447     72.251528      0.316173
# min       -50.800000      0.634000   4963.600000      0.000000
# 25%       -42.700000      1.344000   5099.100000      0.000000
# 50%       -41.800000      4.857000   5191.000000      0.000000
# 75%       -36.400000      4.961000   5228.100000      0.000000
# max       -26.900000      5.045000   5228.100000      1.000000

# %%
fig, axes = plt.subplots(nrows=corr_df.shape[1] // 4 + 1, ncols=4, figsize=(20, 5 * (corr_df.shape[1] // 4 + 1)))

for i, column in enumerate(corr_df.columns):
    sns.boxplot(x=corr_df[column], ax=axes[i // 4, i % 4])

plt.tight_layout()

# %% [markdown]
# We found outliers in cons.conf.idx that i can be replace by mode

# %%
descr = corr_df["cons.conf.idx"].describe()
descr
# Out:
# count    41188.000000
# mean       -40.502600
# std          4.628198
# min        -50.800000
# 25%        -42.700000
# 50%        -41.800000
# 75%        -36.400000
# max        -26.900000
# Name: cons.conf.idx, dtype: float64

# %%
minN_iqr = descr["75%"] - descr["25%"]
upper_l = descr["75%"] + 1.5*minN_iqr
lower_l = descr["25%"] - 1.5*minN_iqr

print(lower_l, upper_l)
outliers = corr_df[corr_df['cons.conf.idx'] >= upper_l]
outliers
# Out:
# -52.150000000000006 -26.949999999999992
#        age  job  marital  default  housing  loan  contact  month  day_of_week  \
# 38154   50    6        0        0        1     0        1      4            3
# 38155   37    2        1        0        1     0        1      4            3
# 38156   59    4        1        0        0     0        1      4            3
# 38157   31    2        0        0        1     0        1      4            3
# 38158   35    2        0        0        1     0        1      4            3
# ...    ...  ...      ...      ...      ...   ...      ...    ...          ...
# 38596   69    5        0        0        1     1        1      4            4
# 38597   18   11        1        0        0     1        1      4            4
# 38598   59    5        2        0        1     0        0      4            4
# 38599   37    2        1        0        0     0        1      4            4
# 38600   78    5        2        0        0     0        0      4            4
#
#        duration  campaign  previous  emp.var.rate  cons.price.idx  \
# 38154       305         2         1          -3.4          92.431
# 38155       447         3         0          -3.4          92.431
# 38156        86         1         2          -3.4          92.431
# 38157       760         1         0          -3.4          92.431
# 38158       194         1         1          -3.4          92.431
# ...         ...       ...       ...           ...             ...
# 38596       257         3         0          -3.4          92.431
# 38597       368         2         0          -3.4          92.431
# 38598       152         4         0          -3.4          92.431
# 38599       416         2         0          -3.4          92.431
# 38600       177         2         0          -3.4          92.431
#
#        cons.conf.idx  euribor3m  nr.employed  y
# 38154          -26.9      0.754       5017.5  1
# 38155          -26.9      0.754       5017.5  1
# 38156          -26.9      0.754       5017.5  0
# 38157          -26.9      0.754       5017.5  0
# 38158          -26.9      0.754       5017.5  1
# ...              ...        ...          ... ..
# 38596          -26.9      0.720       5017.5  1
# 38597          -26.9      0.720       5017.5  1
# 38598          -26.9      0.720       5017.5  0
# 38599          -26.9      0.720       5017.5  1
# 38600          -26.9      0.720       5017.5  0
#
# [447 rows x 18 columns]

# %%
mode = corr_df['cons.conf.idx'].mode()

replace_func = lambda x: x if lower_l <= x <= upper_l else mode
corr_df['cons.conf.idx'] = corr_df['cons.conf.idx'].apply(replace_func)

# %% [markdown]
# Save all dataframes as csv

# %%
df.to_csv('../data/processed/bank-marketing-campaign-data_precleaned.csv', index=False)
corr_df.to_csv('../data/processed/bank-marketing-campaign-data_cleaned.csv', index=False)
outliers.to_csv('../data/processed/bank-marketing-campaign-data_consconfidx-Outliers.csv', index=False)

# %% [markdown]
# #### 5.3 Feature scaling
# First, we divide the data

# %%
corr_df.columns
# Out:
# Index(['age', 'job', 'marital', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'duration', 'campaign', 'previous',
#        'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m',
#        'nr.employed', 'y'],
#       dtype='object')

# %%
predictors = ['age', 'job', 'marital', 'default', 'housing', 'loan', 'contact',
       'month', 'day_of_week', 'duration', 'campaign', 'previous',
       'emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m',
       'nr.employed']
target = 'y'

X = corr_df[predictors]
Y = corr_df[target]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.3, random_state = 42)

X_train.to_csv('../data/processed/bank-marketing-campaign-data_Xtrain_clean.csv', index=False)
X_test.to_csv('../data/processed/bank-marketing-campaign-data_Xtest_clean.csv', index=False)
y_train.to_csv('../data/processed/bank-marketing-campaign-data_ytrain_clean.csv', index=False)
y_test.to_csv('../data/processed/bank-marketing-campaign-data_ytest_clean.csv', index=False)

# %% [markdown]
# #### 5.4 Normalize

# %%
from sklearn.preprocessing import StandardScaler
from pickle import dump

scaler = StandardScaler()
scaler.fit(X_train)

X_train_norm = scaler.transform(X_train)
X_train_norm = pd.DataFrame(X_train_norm, index = X_train.index, columns = predictors)

X_test_norm = scaler.transform(X_test)
X_test_norm = pd.DataFrame(X_test_norm, index = X_test.index, columns = predictors)

dump(scaler, open("../data/processed/normalizer.sav", "wb"))
X_train_norm.to_csv('../data/processed/bank-marketing-campaign-data_norm_Xtrain_clean.csv', index=False)
X_test_norm.to_csv('../data/processed/bank-marketing-campaign-data_norm_Xtest_clean.csv', index=False)

X_train_norm.head()
# Out:
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/utils/_array_api.py:521: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   array = numpy.asarray(array, order=order, dtype=dtype)
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/utils/_array_api.py:521: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   array = numpy.asarray(array, order=order, dtype=dtype)
# /home/vscode/.local/lib/python3.10/site-packages/sklearn/utils/_array_api.py:521: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   array = numpy.asarray(array, order=order, dtype=dtype)
#             age       job   marital   default   housing    loan   contact  \
# 39075 -1.053709 -0.676665 -0.737196 -0.511562 -1.056690 -0.4394  0.756382
# 34855 -1.053709  0.136292  0.699960 -0.511562 -1.056690 -0.4394 -1.322083
# 7107   0.477399 -0.270187 -0.737196  1.953150  0.787018 -0.4394 -1.322083
# 31614 -0.575238 -1.083144 -0.737196 -0.511562 -1.056690 -0.4394  0.756382
# 34878 -0.766626 -0.676665  0.699960 -0.511562 -1.056690 -0.4394  0.756382
#
#           month  day_of_week  duration  campaign  previous  emp.var.rate  \
# 39075  1.543705    -1.407216 -0.695116  0.154139  1.673800     -1.962634
# 34855 -0.931494     1.428361 -0.944916  0.517478 -0.349144     -1.198766
# 7107  -0.931494     0.719467  0.073498 -0.209199 -0.349144      0.647250
# 31614 -0.931494     0.719467 -0.722018 -0.572537  1.673800     -1.198766
# 34878 -0.931494     1.428361  3.547637  2.334170 -0.349144     -1.198766
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 39075       -1.490923       1.723619  -1.678565    -1.978346
# 34855       -1.180409      -1.261065  -1.366780    -0.936182
# 7107         0.718902       0.954836   0.713705     0.330682
# 31614       -1.180409      -1.261065  -1.322404    -0.936182
# 34878       -1.180409      -1.261065  -1.366780    -0.936182

# %% [markdown]
# ### 6.Feature selection

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif # mutual_info is used because there are strongly related variables and target is categorical
selection_model = SelectKBest(mutual_info_classif, k = 10)
selection_model.fit(X_train_norm, y_train)
ix = selection_model.get_support()
X_train_sel = pd.DataFrame(selection_model.transform(X_train_norm), columns = X_train_norm.columns.values[ix])

dump(selection_model, open("../data/processed/selection_model.sav", "wb"))
X_train_sel.to_csv('../data/processed/bank-marketing-campaign-data_norm_Xtrain_clean-featureSel.csv', index=False)

X_train_sel.head()
# Out:
#         age   contact     month  duration  previous  emp.var.rate  \
# 0 -1.053709  0.756382  1.543705 -0.695116  1.673800     -1.962634
# 1 -1.053709 -1.322083 -0.931494 -0.944916 -0.349144     -1.198766
# 2  0.477399 -1.322083 -0.931494  0.073498 -0.349144      0.647250
# 3 -0.575238  0.756382 -0.931494 -0.722018  1.673800     -1.198766
# 4 -0.766626  0.756382 -0.931494  3.547637 -0.349144     -1.198766
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 0       -1.490923       1.723619  -1.678565    -1.978346
# 1       -1.180409      -1.261065  -1.366780    -0.936182
# 2        0.718902       0.954836   0.713705     0.330682
# 3       -1.180409      -1.261065  -1.322404    -0.936182
# 4       -1.180409      -1.261065  -1.366780    -0.936182
